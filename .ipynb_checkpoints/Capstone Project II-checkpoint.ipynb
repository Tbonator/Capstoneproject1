# %% [markdown]
# Exploratory data analysis (EDA) is a crucial component of data science which allows one to understand the basics of what your data looks like and what kinds of questions might be answered by them. For this task, we are going to clean, sanitise and explore our data. Using the movies dataset, answer the following questions by writing code in the cells.

# %%
# Importing the required packages here

import numpy as np
import pandas as pd
import seaborn as sns
import ast, json

from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#### load the movie dataset and create their dataframes

movies_df = pd.read_csv("movies.csv")
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %% [markdown]
# ### Data Cleansing
# #### Clean the data. Identify columns that are redundant or unnecessary.
#
# It is always easier to make your decisions based on data which is relevant and concise. Remove the following columns ['keywords', 'homepage', 'status', 'tagline', 'original_language', 'homepage', 'overview', 'production_companies', 'original_title', 'title_y'] from the data set as they will not be used in the analysis.

# %%
# code here
for col in movies_df.columns: 
    if 'keywords' in col: 
        del movies_df[col]
    elif 'homepage' in col:
        del movies_df[col]
    elif 'status' in col:
        del movies_df[col]
    elif 'tagline' in col:
        del movies_df[col]
    elif 'original_language' in col:
        del movies_df[col]
    elif 'homepage' in col:
        del df[col]
    elif 'overview' in col:
        del movies_df[col]
    elif 'production_companies' in col:
        del movies_df[col]
    elif 'original_title' in col:
        del movies_df[col]
    elif 'title_y' in col:
        del movies_df[col]
        
movies_df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#    popularity                               production_countries release_date  \
# 0  150.437577  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1  139.082615  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2  107.376788  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3  112.312950  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4   43.926995  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
#
#       revenue  runtime                                   spoken_languages  \
# 0  2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1   961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2   880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3  1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4   284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %% [markdown]
# #### Remove any duplicate rows

# %%
# code here
#length before 
length1 = len(movies_df)

# dropping duplicate values 
movies_df.drop_duplicates(keep=False,inplace=True) 
  
# length after removing duplicates 
length2=len(movies_df) 

print(length1,length2)
# Out:
# 4803 4803

# %% [markdown]
# #### Some movies in the database have zero budget or zero revenue which implies that their values have not been recorded or some information is missing. Discard such entries from the dataframe.

# %%
# Code here

# removing rows where revenue is 0
movies_df = movies_df.drop(movies_df[movies_df.revenue == 0].index)
# removing rows where budget is 0
movies_df = movies_df.drop(movies_df[movies_df.budget == 0].index)

movies_df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#    popularity                               production_countries release_date  \
# 0  150.437577  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1  139.082615  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2  107.376788  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3  112.312950  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4   43.926995  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
#
#       revenue  runtime                                   spoken_languages  \
# 0  2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1   961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2   880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3  1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4   284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %% [markdown]
# #### To manipulate the columns easily, it is important that we make use of the python objects. Change the release date column into Date format and extract the year from the date. This will help us in analysing yearly data.

# %%
# Change the release_date column to DateTime column
movies_df['release_date_parsed'] = pd.to_datetime(movies_df['release_date'])

# Extract the release year from every release date

movies_df['release_year'] = pd.DatetimeIndex(movies_df['release_date_parsed']).year
movies_df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#    popularity                               production_countries release_date  \
# 0  150.437577  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1  139.082615  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2  107.376788  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3  112.312950  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4   43.926995  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
#
#       revenue  runtime                                   spoken_languages  \
# 0  2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1   961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2   880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3  1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4   284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124
#
#   release_date_parsed  release_year
# 0          2009-12-10          2009
# 1          2007-05-19          2007
# 2          2015-10-26          2015
# 3          2012-07-16          2012
# 4          2012-03-07          2012

# %% [markdown]
# #### Change budget and revenue columns format to integer using numpy’s int64 method.

# %%
# code here
# converting budget to int64
movies_df['budget'] = pd.to_numeric(movies_df['budget'])
# converting revenue to int64
movies_df['revenue'] = pd.to_numeric(movies_df['revenue'])
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3229 entries, 0 to 4798
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                3229 non-null   int64
#  1   genres                3229 non-null   object
#  2   id                    3229 non-null   int64
#  3   popularity            3229 non-null   float64
#  4   production_countries  3229 non-null   object
#  5   release_date          3229 non-null   object
#  6   revenue               3229 non-null   int64
#  7   runtime               3229 non-null   float64
#  8   spoken_languages      3229 non-null   object
#  9   title                 3229 non-null   object
#  10  vote_average          3229 non-null   float64
#  11  vote_count            3229 non-null   int64
#  12  release_date_parsed   3229 non-null   datetime64[ns]
#  13  release_year          3229 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(5)
# memory usage: 378.4+ KB

# %% [markdown]
# On checking the dataset, we see that genres, keywords, production_companies, production_countries, spoken_languages are in the JSON format which will make it difficult to manipulate the dataframe. Now let’s flatten these columns into a format that can be easily interpreted.
#
# I will help you convert them into strings and later convert them into lists. Writing a generic function to parse JSON columns.

# %%
def parse_col_json(column, key):
    """
    Args:
        column: string
            name of the column to be processed.
        key: string
            name of the dictionary key which needs to be extracted
    """
    for index,i in zip(movies_df.index,movies_df[column].apply(json.loads)):
        list1=[]
        for j in range(len(i)):
            list1.append((i[j][key]))# the key 'name' contains the name of the genre
        movies_df.loc[index,column]=str(list1)
    
#parse_col_json('genres', 'name')
# parse_col_json('spoken_languages', 'name')
parse_col_json('production_countries', 'name')

movies_df.head()
# Out:
#       budget      profit     revenue  \
# 0  237000000  2550965087  2787965087
# 1  300000000   661000000   961000000
# 2  245000000   635674609   880674609
# 3  250000000   834939099  1084939099
# 4  260000000    24139100   284139100
#
#                                               genres      id  popularity  \
# 0  ['Action', 'Adventure', 'Fantasy', 'Science Fi...   19995  150.437577
# 1                 ['Adventure', 'Fantasy', 'Action']     285  139.082615
# 2                   ['Action', 'Adventure', 'Crime']  206647  107.376788
# 3           ['Action', 'Crime', 'Drama', 'Thriller']   49026  112.312950
# 4         ['Action', 'Adventure', 'Science Fiction']   49529   43.926995
#
#                              production_countries release_date  release_year  \
# 0  ['United States of America', 'United Kingdom']   2009-12-10          2009
# 1                    ['United States of America']   2007-05-19          2007
# 2  ['United Kingdom', 'United States of America']   2015-10-26          2015
# 3                    ['United States of America']   2012-07-16          2012
# 4                    ['United States of America']   2012-03-07          2012
#
#    runtime                                   spoken_languages  \
# 0    162.0                             ['English', 'Español']
# 1    169.0                                        ['English']
# 2    148.0  ['Français', 'English', 'Español', 'Italiano',...
# 3    165.0                                        ['English']
# 4    132.0                                        ['English']
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %% [markdown]
# ### Now onto the exploration
#
# #### Identify relationships between variables / features
#
# The main goal here is to identify and create relationships which can help you to build ideas. I have defined questions which can help you identify some relationships to explore.

# %% [markdown]
# #### Which are the 5 most expensive movies? How do the most expensive and cheapest movies compare? Exploring the most expensive movies help you explore if some movies are worth the money spent on them based on their performance and revenue generated.

# %%
# Code here

expensive_movies_df = movies_df.sort_values(by ='budget', ascending=False).head()
movies_df.sort_values(by = ['budget'], ascending=False).head()
# Out:
#        budget      profit     revenue  \
# 17  380000000   665713802  1045713802
# 1   300000000   661000000   961000000
# 7   280000000  1125403694  1405403694
# 10  270000000   121081192   391081192
# 4   260000000    24139100   284139100
#
#                                                genres     id  popularity  \
# 17                 ['Adventure', 'Action', 'Fantasy']   1865  135.413856
# 1                  ['Adventure', 'Fantasy', 'Action']    285  139.082615
# 7          ['Action', 'Adventure', 'Science Fiction']  99861  134.279229
# 10  ['Adventure', 'Fantasy', 'Action', 'Science Fi...   1452   57.925623
# 4          ['Action', 'Adventure', 'Science Fiction']  49529   43.926995
#
#             production_countries release_date  release_year  runtime  \
# 17  ['United States of America']   2011-05-14          2011    136.0
# 1   ['United States of America']   2007-05-19          2007    169.0
# 7   ['United States of America']   2015-04-22          2015    141.0
# 10  ['United States of America']   2006-06-28          2006    154.0
# 4   ['United States of America']   2012-03-07          2012    132.0
#
#                       spoken_languages  \
# 17              ['English', 'Español']
# 1                          ['English']
# 7                          ['English']
# 10  ['English', 'Français', 'Deutsch']
# 4                          ['English']
#
#                                           title  vote_average  vote_count
# 17  Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 1      Pirates of the Caribbean: At World's End           6.9        4500
# 7                       Avengers: Age of Ultron           7.3        6767
# 10                             Superman Returns           5.4        1400
# 4                                   John Carter           6.1        2124

# %% [markdown]
# #### What are the top 5 most profitable movies? Compare the min and max profits. The comparison helps us indentify the different approaches which failed and succeeded. Subtracting the budget from the revenue generated, will return the profit earned.

# %%
# code here

movies_df['profit'] = movies_df['revenue'] - movies_df['budget']
cols = ['budget',
         'profit',
         'revenue',
         'genres',
         'id',
         'popularity',
         'production_countries',
        'release_date',
        'release_year',
         'runtime',
         'spoken_languages',
         'title',
         'vote_average',
         'vote_count']
movies_df = movies_df[cols]
movies_df.sort_values(by = ['budget'], ascending=False).head()
# Out:
#        budget      profit     revenue  \
# 17  380000000   665713802  1045713802
# 1   300000000   661000000   961000000
# 7   280000000  1125403694  1405403694
# 10  270000000   121081192   391081192
# 4   260000000    24139100   284139100
#
#                                                genres     id  popularity  \
# 17                 ['Adventure', 'Action', 'Fantasy']   1865  135.413856
# 1                  ['Adventure', 'Fantasy', 'Action']    285  139.082615
# 7          ['Action', 'Adventure', 'Science Fiction']  99861  134.279229
# 10  ['Adventure', 'Fantasy', 'Action', 'Science Fi...   1452   57.925623
# 4          ['Action', 'Adventure', 'Science Fiction']  49529   43.926995
#
#             production_countries release_date  release_year  runtime  \
# 17  ['United States of America']   2011-05-14          2011    136.0
# 1   ['United States of America']   2007-05-19          2007    169.0
# 7   ['United States of America']   2015-04-22          2015    141.0
# 10  ['United States of America']   2006-06-28          2006    154.0
# 4   ['United States of America']   2012-03-07          2012    132.0
#
#                       spoken_languages  \
# 17              ['English', 'Español']
# 1                          ['English']
# 7                          ['English']
# 10  ['English', 'Français', 'Deutsch']
# 4                          ['English']
#
#                                           title  vote_average  vote_count
# 17  Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 1      Pirates of the Caribbean: At World's End           6.9        4500
# 7                       Avengers: Age of Ultron           7.3        6767
# 10                             Superman Returns           5.4        1400
# 4                                   John Carter           6.1        2124

# %% [markdown]
# #### Find the most talked about movies. Sort the dataframe based on the popularity column.

# %%
popular_movies_df = movies_df.sort_values(by ='budget', ascending=False).head()
popular_movies_df.head()
# Out:
#        budget      profit     revenue  \
# 17  380000000   665713802  1045713802
# 1   300000000   661000000   961000000
# 7   280000000  1125403694  1405403694
# 10  270000000   121081192   391081192
# 4   260000000    24139100   284139100
#
#                                                genres     id  popularity  \
# 17                 ['Adventure', 'Action', 'Fantasy']   1865  135.413856
# 1                  ['Adventure', 'Fantasy', 'Action']    285  139.082615
# 7          ['Action', 'Adventure', 'Science Fiction']  99861  134.279229
# 10  ['Adventure', 'Fantasy', 'Action', 'Science Fi...   1452   57.925623
# 4          ['Action', 'Adventure', 'Science Fiction']  49529   43.926995
#
#             production_countries release_date  release_year  runtime  \
# 17  ['United States of America']   2011-05-14          2011    136.0
# 1   ['United States of America']   2007-05-19          2007    169.0
# 7   ['United States of America']   2015-04-22          2015    141.0
# 10  ['United States of America']   2006-06-28          2006    154.0
# 4   ['United States of America']   2012-03-07          2012    132.0
#
#                       spoken_languages  \
# 17              ['English', 'Español']
# 1                          ['English']
# 7                          ['English']
# 10  ['English', 'Français', 'Deutsch']
# 4                          ['English']
#
#                                           title  vote_average  vote_count
# 17  Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 1      Pirates of the Caribbean: At World's End           6.9        4500
# 7                       Avengers: Age of Ultron           7.3        6767
# 10                             Superman Returns           5.4        1400
# 4                                   John Carter           6.1        2124

# %% [markdown]
# #### Find Movies which are rated above 7

# %%
# Code here

movies_df[movies_df['vote_average'] >= 7.0]
# Out:
#          budget      profit     revenue  \
# 0     237000000  2550965087  2787965087
# 3     250000000   834939099  1084939099
# 6     260000000   331794936   591794936
# 7     280000000  1125403694  1405403694
# 8     250000000   683959197   933959197
# ...         ...         ...         ...
# 4713     160000     6546368     6706368
# 4724      10000     6990000     7000000
# 4738      60000     3161152     3221152
# 4773      27000     3124130     3151130
# 4792      20000       79000       99000
#
#                                                  genres     id  popularity  \
# 0     ['Action', 'Adventure', 'Fantasy', 'Science Fi...  19995  150.437577
# 3              ['Action', 'Crime', 'Drama', 'Thriller']  49026  112.312950
# 6                               ['Animation', 'Family']  38757   48.681969
# 7            ['Action', 'Adventure', 'Science Fiction']  99861  134.279229
# 8                    ['Adventure', 'Fantasy', 'Family']    767   98.885637
# ...                                                 ...    ...         ...
# 4713                         ['Documentary', 'History']   1779    3.284903
# 4724  ['Drama', 'Fantasy', 'Horror', 'Science Fiction']    985   20.399578
# 4738                   ['Mystery', 'Drama', 'Thriller']    473   27.788067
# 4773                                         ['Comedy']   2292   19.748658
# 4792         ['Crime', 'Horror', 'Mystery', 'Thriller']  36095    0.212443
#
#                                 production_countries release_date  \
# 0     ['United States of America', 'United Kingdom']   2009-12-10
# 3                       ['United States of America']   2012-07-16
# 6                       ['United States of America']   2010-11-24
# 7                       ['United States of America']   2015-04-22
# 8     ['United Kingdom', 'United States of America']   2009-07-07
# ...                                              ...          ...
# 4713                    ['United States of America']   1989-09-01
# 4724                    ['United States of America']   1977-03-19
# 4738                    ['United States of America']   1998-07-10
# 4773                    ['United States of America']   1994-09-13
# 4792                                       ['Japan']   1997-11-06
#
#       release_year  runtime        spoken_languages  \
# 0             2009    162.0  ['English', 'Español']
# 3             2012    165.0             ['English']
# 6             2010    100.0             ['English']
# 7             2015    141.0             ['English']
# 8             2009    153.0             ['English']
# ...            ...      ...                     ...
# 4713          1989     91.0             ['English']
# 4724          1977     89.0             ['English']
# 4738          1998     84.0             ['English']
# 4773          1994     92.0             ['English']
# 4792          1997    111.0                 ['日本語']
#
#                                        title  vote_average  vote_count
# 0                                     Avatar           7.2       11800
# 3                      The Dark Knight Rises           7.6        9106
# 6                                    Tangled           7.4        3330
# 7                    Avengers: Age of Ultron           7.3        6767
# 8     Harry Potter and the Half-Blood Prince           7.4        5293
# ...                                      ...           ...         ...
# 4713                              Roger & Me           7.4          90
# 4724                              Eraserhead           7.5         485
# 4738                                      Pi           7.1         586
# 4773                                  Clerks           7.4         755
# 4792                                    Cure           7.4          63
#
# [768 rows x 14 columns]

# %% [markdown]
# #### Which year did we have the most profitable movies?
# This will help to raise some deeper questions about the years when movies didn’t do well. These are preliminary questions which give rise to questions providing deeper insights.

# %%
# Code here

profits_year.idxmax()
# Out:
# 2014

# %% [markdown]
# #### Most successful genres — create a bar plot explaining the frequency of movies in each genre.

# %%
 # Code here
    
#selecting the movies having profit $50M or more
profit_data = movies_df[movies_df['profit'] >= 50000000]

#reindexing new data
profit_data.index = range(len(profit_data))

#we will start from 1 instead of 0
profit_data.index = profit_data.index + 1

#printing the changed dataset
profit_data.head(3)
# Out:
#       budget      profit     revenue  \
# 1  237000000  2550965087  2787965087
# 2  300000000   661000000   961000000
# 3  245000000   635674609   880674609
#
#                                               genres      id  popularity  \
# 1  ['Action', 'Adventure', 'Fantasy', 'Science Fi...   19995  150.437577
# 2                 ['Adventure', 'Fantasy', 'Action']     285  139.082615
# 3                   ['Action', 'Adventure', 'Crime']  206647  107.376788
#
#                              production_countries release_date  release_year  \
# 1  ['United States of America', 'United Kingdom']   2009-12-10          2009
# 2                    ['United States of America']   2007-05-19          2007
# 3  ['United Kingdom', 'United States of America']   2015-10-26          2015
#
#    runtime                                   spoken_languages  \
# 1    162.0                             ['English', 'Español']
# 2    169.0                                        ['English']
# 3    148.0  ['Français', 'English', 'Español', 'Italiano',...
#
#                                       title  vote_average  vote_count
# 1                                    Avatar           7.2       11800
# 2  Pirates of the Caribbean: At World's End           6.9        4500
# 3                                   Spectre           6.3        4466

# %%
# formatting the data in the genres columns.
profit_data = movies_df[movies_df['profit'] >= 50000000]
profit_data.loc[:,'genres']=profit_data['genres'].str.strip('[]').str.replace(' ','').str.replace("'",'')

profit_data.loc[:,'genres'] = profit_data['genres'].str.split(',')

profit_data.head()
# Out:
# C:\Users\Thabo Moeketsi\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
#       budget      profit     revenue  \
# 0  237000000  2550965087  2787965087
# 1  300000000   661000000   961000000
# 2  245000000   635674609   880674609
# 3  250000000   834939099  1084939099
# 5  258000000   632871626   890871626
#
#                                          genres      id  popularity  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]   19995  150.437577
# 1                  [Adventure, Fantasy, Action]     285  139.082615
# 2                    [Action, Adventure, Crime]  206647  107.376788
# 3              [Action, Crime, Drama, Thriller]   49026  112.312950
# 5                  [Fantasy, Action, Adventure]     559  115.699814
#
#                              production_countries release_date  release_year  \
# 0  ['United States of America', 'United Kingdom']   2009-12-10          2009
# 1                    ['United States of America']   2007-05-19          2007
# 2  ['United Kingdom', 'United States of America']   2015-10-26          2015
# 3                    ['United States of America']   2012-07-16          2012
# 5                    ['United States of America']   2007-05-01          2007
#
#    runtime                                   spoken_languages  \
# 0    162.0                             ['English', 'Español']
# 1    169.0                                        ['English']
# 2    148.0  ['Français', 'English', 'Español', 'Italiano',...
# 3    165.0                                        ['English']
# 5    139.0                            ['English', 'Français']
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576

# %%
#### Generate three different interesting visualisations with a data story.

plt.subplots(figsize=(12,10))
list1=[]

# extending the list to 
for i in profit_data['genres']:
    list1.extend(i)
    
ax = pd.Series(list1).value_counts()[:10].sort_values(ascending=True).plot.barh(
    width=0.9,
    color=sns.color_palette('summer_r',10))

for i, v in enumerate(pd.Series(list1).value_counts()[:10].sort_values(ascending=True).values): 
    ax.text(.8, i, v,fontsize=12,color='white',weight='bold')
ax.patches[9].set_facecolor('r')
plt.title('Top Genres')
plt.show()

# %%
# Year we had the most number of profitable movies.
# we'll first have to define a profitable movies

#plotting a histogram of runtime of movies

#giving the figure size(width, height)
plt.figure(figsize=(9,5), dpi = 100)

#On x-axis 
plt.xlabel('Runtime of the Movies', fontsize = 15)
#On y-axis 
plt.ylabel('Nos.of Movies in the Dataset', fontsize=15)
#Name of the graph
plt.title('Runtime of all the movies', fontsize=15)

#giving a histogram plot
plt.hist(movies_df['runtime'], rwidth = 0.9, bins =35)
#displays the plot
plt.show()

# %%
profits_year = movies_df.groupby('release_year')['profit'].sum()

#figure size(width, height)
plt.figure(figsize=(12,6), dpi = 130)

#on x-axis
plt.xlabel('Release Year of Movies in the data set', fontsize = 12)
#on y-axis
plt.ylabel('Profits earned by Movies', fontsize = 12)
#title of the line plot
plt.title('Representing Total Profits earned by all movies Vs Year of their release.')

#plotting the graph
plt.plot(profits_year)

#displaying the line plot
plt.show()

# %% [markdown]
# # Now that you know how to Explore a Dataset, it's time for you to do it from start to end. Please find the Automobile Dataset in your task folder.
#
# ### You are expected to create a report ('eda.docx' provides a template for what this report should look like) in which you explain your visualisations, investigations and findings. The Code for the Analysis should be in a jupyter notebook named automobile.ipynb.
#
# ## Be creative :)
